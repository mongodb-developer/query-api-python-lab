# %% [markdown]
# [![Aggregation Pipeline Lab](https://img.shields.io/badge/Lab%20Documentation%20and%20Solutions-darkgreen)](https://mongodb-developer.github.io/search-lab/)

# %% [markdown]
# # Full Text Search - Create FTS Index

# %% [markdown]
# ## Startup code

# %%
# Import the MongoDB Driver
from pymongo import MongoClient

# Set your connection String
mongoDBURI = "mongodb://admin:mongodb@localhost:27017/?directConnection=true";

# Create a MongoDB Client
client = MongoClient(mongoDBURI)

# Get the Library Database
db = client["library"]

# Get the Books Collection
books = db["books"]

# %% [markdown]
# ## create_search_index()
#
# https://www.mongodb.com/docs/languages/python/pymongo-driver/current/indexes/#create-a-search-index

# %%
books.create_search_index({
    "name": "default",
    "definition": {
        "mappings": {
            "dynamic": True
        }
    }
})

# %% [markdown]
# ## Check that the index has been created

# %%
# List Existing Search Indexes
indexes = list(books.list_search_indexes())
for index in indexes:
    print(f"Indexes: {indexes}")
